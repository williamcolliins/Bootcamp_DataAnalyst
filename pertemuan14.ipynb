# %% [markdown]
# PENDEKATAN PROSEDURAL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("penyakit_jantung.csv")
data
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63  female   3       145   233    1        0      150      0      2.3
# 1     37  female   2       130   250    0        1      187      0      3.5
# 2     41    male   1       130   204    0        0      172      0      1.4
# 3     56  female   1       120   236    0        1      178      0      0.8
# 4     57    male   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    male   0       140   241    0        1      123      1      0.2
# 299   45  female   3       110   264    0        1      132      0      1.2
# 300   68  female   0       144   193    1        1      141      0      3.4
# 301   57  female   0       130   131    0        1      115      1      1.2
# 302   57    male   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %%
trestbps = data.groupby("age")["trestbps"].sum()
chol = data.groupby("age")["chol"].sum()

sns.lineplot(x = trestbps.index, y = trestbps.values, label = "trestbps")
sns.lineplot(x = chol.index, y = chol.values, label = "chol")
plt.legend()

# %%
plt.subplot(121) # (baris, kolom, letak plot)
sns.lineplot(x = trestbps.index, y = trestbps.values)
plt.xlabel("Age")
plt.ylabel("Trestbps")

plt.subplot(122)
sns.lineplot(x = chol.index, y = chol.values, color = "red")
plt.xlabel("Age")
plt.ylabel("Chol")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(121) # (baris, kolom, letak plot)
sns.lineplot(x = trestbps.index, y = trestbps.values)
plt.xlabel("Age")
plt.ylabel("Trestbps")

plt.subplot(122)
sns.scatterplot(x = chol.index, y = chol.values, color = "red")
plt.xlabel("Age")
plt.ylabel("Chol")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# PENDEKATAN OBJECT ORIENTED

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,0.7,0.9]) # (left, bottom, width, height)
axes.plot(trestbps.index, trestbps.values)
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1.3,1.2]) # (left, bottom, width, height)
axes1.plot(trestbps.index, trestbps.values)
axes1.set_xlabel("Age")
axes1.set_ylabel("Trestbps")

axes2 = fig.add_axes([0.2,0.8,0.3,0.3])
axes2.plot(chol.index, chol.values, color = "green")
axes2.set_xlabel("Age")
axes2.set_ylabel("Chol")
# Out:
# Text(0, 0.5, 'Chol')

# %%
fig, axes = plt.subplots(2,2) # (baris,kolom)

# baris 1 kolom 1
axes[0][0].plot(trestbps.index, trestbps.values, color="red")

# baris 1 kolom 2
axes[0][1].plot(trestbps.index, trestbps.values, color="blue")

# baris 2 kolom 1
axes[1][0].plot(trestbps.index, trestbps.values, color="green")

# baris 2 kolom 2
axes[1][1].plot(trestbps.index, trestbps.values, color="purple")

fig.tight_layout()

# %% [markdown]
# ASSIGNMENT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataSS = pd.read_csv("SampleSuperstore.csv")
dataSS.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
dataSS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9993 non-null   object
#  1   Segment       9993 non-null   object
#  2   Country       9993 non-null   object
#  3   City          9993 non-null   object
#  4   State         9993 non-null   object
#  5   Postal Code   9993 non-null   int64
#  6   Region        9993 non-null   object
#  7   Category      9993 non-null   object
#  8   Sub-Category  9993 non-null   object
#  9   Sales         9993 non-null   float64
#  10  Quantity      9993 non-null   int64
#  11  Discount      9993 non-null   float64
#  12  Profit        9993 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.0+ KB

# %% [markdown]
# 1

# %%
dataSS.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
dataSS.duplicated().sum()
# Out:
# np.int64(17)

# %%
dataSS.drop_duplicates(inplace=True)

# %%
dataSS.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataSS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9976 entries, 0 to 9992
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9976 non-null   object
#  1   Segment       9976 non-null   object
#  2   Country       9976 non-null   object
#  3   City          9976 non-null   object
#  4   State         9976 non-null   object
#  5   Postal Code   9976 non-null   int64
#  6   Region        9976 non-null   object
#  7   Category      9976 non-null   object
#  8   Sub-Category  9976 non-null   object
#  9   Sales         9976 non-null   float64
#  10  Quantity      9976 non-null   int64
#  11  Discount      9976 non-null   float64
#  12  Profit        9976 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# 2

# %%
ship = dataSS.groupby('Ship Mode')['Ship Mode'].count()
print(ship)
# Out:
# Ship Mode
# First Class       1537
# Same Day           542
# Second Class      1942
# Standard Class    5955
# Name: Ship Mode, dtype: int64

# %%
sns.barplot(x = ship.index, y = ship.values)
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
ship.idxmax()
# Out:
# 'Standard Class'

# %% [markdown]
# 3

# %%
region = dataSS.groupby('Region')['Sales'].sum()

print(f"sales tertinggi : {region.idxmax()}")
print(f"sales terendah : {region.idxmin()}")
sns.barplot(y = region.index, x = region.values)
# Out:
# sales tertinggi : West
# sales terendah : South
# <Axes: ylabel='Region'>

# %% [markdown]
# 4

# %%
profitsales_percategory = dataSS.groupby('Category')[['Profit', 'Sales']].sum()
profitsales_percategory
# Out:
#                       Profit        Sales
# Category
# Furniture         18421.8137  741306.3133
# Office Supplies  122291.7128  718492.0840
# Technology       145454.9481  836154.0330

# %%
profitsales_percategory.index
# Out:
# Index(['Furniture', 'Office Supplies', 'Technology'], dtype='object', name='Category')

# %%
profitsales_percategory.values
# Out:
# array([[ 18421.8137, 741306.3133],
#        [122291.7128, 718492.084 ],
#        [145454.9481, 836154.033 ]])

# %%
sns.lineplot(x = profitsales_percategory.index, y = profitsales_percategory.values[0: 0], label = 'Profit')
sns.linelot(x = profitsales_percategory.index, y = profitsales_percategory.values[0: 1], label = 'Sales')
plt.title('Profit And Sales Per Category')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ...

# %%
print(f"Kategori hasil tertinggi: \n{profitsales_percategory.idxmax()}")
print(f"Kategori hasil terendah: \n{profitsales_percategory.idxmin()}")
# Out:
# Kategori hasil tertinggi:
# Profit    Technology
# Sales     Technology
# dtype: object
# Kategori hasil terendah:
# Profit          Furniture
# Sales     Office Supplies
# dtype: object

# %% [markdown]
# 5

# %%
sns.scatterplot(x = 'Discount', y = 'Profit', data = dataSS)
plt.title('Discount vs Profit')
plt.show()
